# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayalaxmichindi2007/hanuman/blob/main/CIE_2_ANSWERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/titanic.csv02.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0    0.0      211536  13.00   NaN        S
# 887  female  19.0      0    0.0      112053  30.00   B42        S
# 888  female   NaN      1    2.0  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0    0.0      111369  30.00  C148        C
# 890    male  32.0      0    0.0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          709 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        889 non-null    float64
#  8   Ticket       879 non-null    object
#  9   Fare         881 non-null    float64
#  10  Cabin        203 non-null    object
#  11  Embarked     887 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  709.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.750592    0.523008
# std     257.353842    0.486592    0.836071   14.533187    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.500000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  881.000000
# mean     0.382452   32.120379
# std      0.806761   49.327596
# min      0.000000    0.000000
# 25%      0.000000    7.925000
# 50%      0.000000   14.454200
# 75%      0.000000   31.275000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            182
# SibSp            0
# Parch            2
# Ticket          12
# Fare            10
# Cabin          688
# Embarked         4
# dtype: int64

# %%
print(df['Age'].isna().sum())
# Out:
# 182

# %%
print(df['Survived'].isna().sum())
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
titanic=sns.load_dataset('titanic')
sns.boxplot(x='pclass',y='age',hue='sex',data=titanic)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
