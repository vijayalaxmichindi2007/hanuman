# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayalaxmichindi2007/hanuman/blob/main/answers3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/MT_Cars.csv')
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df.drop('mpg',axis=1)
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0     6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1     6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2     4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4     8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5     6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6     8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7     4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8     4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9     6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['drat'] = le.fit_transform(df['drat'])
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# 8   22.8    4  140.8   95    16  3.150  22.90   1   0     4     2      0
# 9   19.2    6  167.6  123    16  3.440  18.30   1   0     4     4      1
# 10  17.8    6  167.6  123    16  3.440  18.90   1   0     4     4      1
# 11  16.4    8  275.8  180     3  4.070  17.40   0   0     3     3      2
# ...

# %%
df.isnull().sum()
# Out:
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# cyl\t    0
# dtype: int64

# %%
df.fillna(method='ffill',)
# Out:
# /tmp/ipython-input-3271513254.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',)
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# 8   22.8    4  140.8   95    16  3.150  22.90   1   0     4     2      0
# ...

# %%
x=df.iloc[:,1:8]
y=df[['mpg']]
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# 8   22.8    4  140.8   95    16  3.150  22.90   1   0     4     2      0
# 9   19.2    6  167.6  123    16  3.440  18.30   1   0     4     4      1
# 10  17.8    6  167.6  123    16  3.440  18.90   1   0     4     4      1
# 11  16.4    8  275.8  180     3  4.070  17.40   0   0     3     3      2
# ...

# %%
x
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs
# 0     6  160.0  110    15  2.620  16.46   0
# 1     6  160.0  110    15  2.875  17.02   0
# 2     4  108.0   93    14  2.320  18.61   1
# 3     6  258.0  110     4  3.215  19.44   1
# 4     8  360.0  175     5  3.440  17.02   0
# 5     6  225.0  105     0  3.460  20.22   1
# 6     8  360.0  245     6  3.570  15.84   0
# 7     4  146.7   62    10  3.190  20.00   1
# 8     4  140.8   95    16  3.150  22.90   1
# 9     6  167.6  123    16  3.440  18.30   1
# 10    6  167.6  123    16  3.440  18.90   1
# 11    8  275.8  180     3  4.070  17.40   0
# 12    8  275.8  180     3  3.730  17.60   0
# 13    8  275.8  180     3  3.780  18.00   0
# 14    8  472.0  205     1  5.250  17.98   0
# 15    8  460.0  215     2  5.424  17.82   0
# 16    8  440.0  230     7  5.345  17.42   0
# 17    4   78.7   66    17  2.200  19.47   1
# 18    4   75.7   52    21  1.615  18.52   1
# 19    4   71.1   65    19  1.835  19.90   1
# ...

# %%
y
# Out:
#      mpg
# 0   21.0
# 1   21.0
# 2   22.8
# 3   21.4
# 4   18.7
# 5   18.1
# 6   14.3
# 7   24.4
# 8   22.8
# 9   19.2
# 10  17.8
# 11  16.4
# 12  17.3
# 13  15.2
# 14  10.4
# 15  10.4
# 16  14.7
# 17  32.4
# 18  30.4
# 19  33.9
# 20  21.5
# 21  15.5
# 22  15.2
# 23  13.3
# 24  19.2
# 25  27.3
# 26  26.0
# 27  30.4
# 28  15.8
# 29  19.7
# 30  15.0
# 31  21.4

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# 8   22.8    4  140.8   95    16  3.150  22.90   1   0     4     2      0
# 9   19.2    6  167.6  123    16  3.440  18.30   1   0     4     4      1
# 10  17.8    6  167.6  123    16  3.440  18.90   1   0     4     4      1
# 11  16.4    8  275.8  180     3  4.070  17.40   0   0     3     3      2
# ...

# %%
x_train
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs
# 12    8  275.8  180     3  3.730  17.60   0
# 0     6  160.0  110    15  2.620  16.46   0
# 4     8  360.0  175     5  3.440  17.02   0
# 16    8  440.0  230     7  5.345  17.42   0
# 5     6  225.0  105     0  3.460  20.22   1
# 13    8  275.8  180     3  3.780  18.00   0
# 11    8  275.8  180     3  4.070  17.40   0
# 23    8  350.0  245    12  3.840  15.41   0
# 1     6  160.0  110    15  2.875  17.02   0
# 2     4  108.0   93    14  2.320  18.61   1
# 26    4  120.3   91    20  2.140  16.70   0
# 3     6  258.0  110     4  3.215  19.44   1
# 21    8  318.0  150     0  3.520  16.87   0
# 27    4   95.1  113    13  1.513  16.90   1
# 22    8  304.0  150     5  3.435  17.30   0
# 18    4   75.7   52    21  1.615  18.52   1
# 31    4  121.0  109    18  2.780  18.60   1
# 20    4  120.1   97    11  2.465  20.01   1
# 7     4  146.7   62    10  3.190  20.00   1
# 10    6  167.6  123    16  3.440  18.90   1
# ...

# %%
x_test
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs
# 29    6  145.0  175     9  2.770  15.50   0
# 15    8  460.0  215     2  5.424  17.82   0
# 24    8  400.0  175     4  3.845  17.05   0
# 17    4   78.7   66    17  2.200  19.47   1
# 8     4  140.8   95    16  3.150  22.90   1
# 9     6  167.6  123    16  3.440  18.30   1
# 30    8  301.0  335     8  3.570  14.60   0
# 25    4   79.0   66    17  1.935  18.90   1

# %%
y_train
# Out:
#      mpg
# 12  17.3
# 0   21.0
# 4   18.7
# 16  14.7
# 5   18.1
# 13  15.2
# 11  16.4
# 23  13.3
# 1   21.0
# 2   22.8
# 26  26.0
# 3   21.4
# 21  15.5
# 27  30.4
# 22  15.2
# 18  30.4
# 31  21.4
# 20  21.5
# 7   24.4
# 10  17.8
# 14  10.4
# 28  15.8
# 19  33.9
# 6   14.3

# %%
y_test
# Out:
#      mpg
# 29  19.7
# 15  10.4
# 24  19.2
# 17  32.4
# 8   22.8
# 9   19.2
# 30  15.0
# 25  27.3

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=100, random_state=0)
rfr.fit(x_train,y_train)
df
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# ...

# %%
y_pred1 = rfr.predict(x_test)
y_pred1
# Out:
# array([19.36 , 12.264, 15.925, 28.142, 22.62 , 18.594, 14.842, 30.582])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
mse_RFR=mean_squared_error(y_test,y_pred1)
mae_RFR=mean_absolute_error(y_test,y_pred1)
r2_RFR=r2_score(y_test,y_pred1)
rmse_RFR=np.sqrt(mse_RFR)
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# 8   22.8    4  140.8   95    16  3.150  22.90   1   0     4     2      0
# 9   19.2    6  167.6  123    16  3.440  18.30   1   0     4     4      1
# 10  17.8    6  167.6  123    16  3.440  18.90   1   0     4     4      1
# 11  16.4    8  275.8  180     3  4.070  17.40   0   0     3     3      2
# ...

# %%
print("Mean_Squared_Error:-",mse_RFR)
print("Mean_Absolute_Error:-",mae_RFR)
print("Root_Mean_Squared_Error:-",rmse_RFR)
print("R2_Score:-",r2_RFR)
# Out:
# Mean_Squared_Error:- 5.455301124999992
# Mean_Absolute_Error:- 1.7453750000000017
# Root_Mean_Squared_Error:- 2.335658606260768
# R2_Score:- 0.8673160373343064

# %%
from sklearn.svm import SVR
SVR=SVR(kernel='rbf')
SVR.fit(x_train,y_train)
df
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# ...

# %%
y_pred2 = SVR.predict(x_test)
y_pred2
# Out:
# array([20.27363164, 15.24507512, 15.43231777, 22.26090343, 21.30125227,
#        20.47759605, 16.40602229, 22.2590168 ])

# %%
mse_SVR=mean_squared_error(y_test,y_pred2)
mae_SVR=mean_absolute_error(y_test,y_pred2)
r2_SVR=r2_score(y_test,y_pred2)
rmse_SVR=np.sqrt(mse_SVR)
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  cyl\t
# 0   21.0    6  160.0  110    15  2.620  16.46   0   1     4     4      1
# 1   21.0    6  160.0  110    15  2.875  17.02   0   1     4     4      1
# 2   22.8    4  108.0   93    14  2.320  18.61   1   1     4     1      0
# 3   21.4    6  258.0  110     4  3.215  19.44   1   0     3     1      1
# 4   18.7    8  360.0  175     5  3.440  17.02   0   0     3     2      2
# 5   18.1    6  225.0  105     0  3.460  20.22   1   0     3     1      1
# 6   14.3    8  360.0  245     6  3.570  15.84   0   0     3     4      2
# 7   24.4    4  146.7   62    10  3.190  20.00   1   0     4     2      0
# 8   22.8    4  140.8   95    16  3.150  22.90   1   0     4     2      0
# 9   19.2    6  167.6  123    16  3.440  18.30   1   0     4     4      1
# 10  17.8    6  167.6  123    16  3.440  18.90   1   0     4     4      1
# 11  16.4    8  275.8  180     3  4.070  17.40   0   0     3     3      2
# ...

# %%
print("Mean_Squared_Error:-",mse_SVR)
print("Mean_Absolute_Error:-",mae_SVR)
print("Root_Mean_Squared_Error:-",rmse_SVR)
print("R2_Score:-",r2_SVR)
# Out:
# Mean_Squared_Error:- 21.508427695981776
# Mean_Absolute_Error:- 3.568604353162147
# Root_Mean_Squared_Error:- 4.637717940537326
# R2_Score:- 0.4768715141436999
